# %% [markdown]
# List the files in the results directory:

# %%
# !ls ../results/
# Out:
# ior_h5_n16_M1_T128.out  ior_mpi_n4_M4_T8.out    ior_psx_n2_M2_T256.out
# ior_h5_n16_M1_T16.out   ior_mpi_n4_M8_T128.out  ior_psx_n2_M2_T32.out
# ior_h5_n16_M1_T256.out  ior_mpi_n4_M8_T16.out   ior_psx_n2_M2_T64.out
# ior_h5_n16_M1_T32.out   ior_mpi_n4_M8_T256.out  ior_psx_n2_M2_T8.out
# ior_h5_n16_M1_T64.out   ior_mpi_n4_M8_T32.out   ior_psx_n2_M4_T128.out
# ior_h5_n16_M1_T8.out    ior_mpi_n4_M8_T64.out   ior_psx_n2_M4_T16.out
# ior_h5_n16_M2_T128.out  ior_mpi_n4_M8_T8.out    ior_psx_n2_M4_T256.out
# ior_h5_n16_M2_T16.out   ior_mpi_n64_M1_T128.out ior_psx_n2_M4_T32.out
# ior_h5_n16_M2_T256.out  ior_mpi_n64_M1_T16.out  ior_psx_n2_M4_T64.out
# ior_h5_n16_M2_T32.out   ior_mpi_n64_M1_T256.out ior_psx_n2_M4_T8.out
# ior_h5_n16_M2_T64.out   ior_mpi_n64_M1_T32.out  ior_psx_n2_M8_T128.out
# ior_h5_n16_M2_T8.out    ior_mpi_n64_M1_T64.out  ior_psx_n2_M8_T16.out
# ior_h5_n16_M4_T128.out  ior_mpi_n64_M1_T8.out   ior_psx_n2_M8_T256.out
# ior_h5_n16_M4_T16.out   ior_mpi_n64_M2_T128.out ior_psx_n2_M8_T32.out
# ior_h5_n16_M4_T256.out  ior_mpi_n64_M2_T16.out  ior_psx_n2_M8_T64.out
# ior_h5_n16_M4_T32.out   ior_mpi_n64_M2_T256.out ior_psx_n2_M8_T8.out
# ior_h5_n16_M4_T64.out   ior_mpi_n64_M2_T32.out  ior_psx_n32_M1_T128.out
# ior_h5_n16_M4_T8.out    ior_mpi_n64_M2_T64.out  ior_psx_n32_M1_T16.out
# ior_h5_n16_M8_T128.out  ior_mpi_n64_M2_T8.out   ior_psx_n32_M1_T256.out
# ior_h5_n16_M8_T16.out   ior_mpi_n64_M4_T128.out ior_psx_n32_M1_T32.out
# ior_h5_n16_M8_T256.out  ior_mpi_n64_M4_T16.out  ior_psx_n32_M1_T64.out
# ior_h5_n16_M8_T32.out   ior_mpi_n64_M4_T256.out ior_psx_n32_M1_T8.out
# ior_h5_n16_M8_T64.out   ior_mpi_n64_M4_T32.out  ior_psx_n32_M2_T128.out
# ior_h5_n16_M8_T8.out    ior_mpi_n64_M4_T64.out  ior_psx_n32_M2_T16.out
# ior_h5_n1_M1_T128.out   ior_mpi_n64_M4_T8.out   ior_psx_n32_M2_T256.out
# ior_h5_n1_M1_T16.out    ior_mpi_n64_M8_T128.out ior_psx_n32_M2_T32.out
# ior_h5_n1_M1_T256.out   ior_mpi_n64_M8_T16.out  ior_psx_n32_M2_T64.out
# ior_h5_n1_M1_T32.out    ior_mpi_n64_M8_T256.out ior_psx_n32_M2_T8.out
# ior_h5_n1_M1_T64.out    ior_mpi_n64_M8_T32.out  ior_psx_n32_M4_T128.out
# ior_h5_n1_M1_T8.out     ior_mpi_n64_M8_T64.out  ior_psx_n32_M4_T16.out
# ior_h5_n1_M2_T128.out   ior_mpi_n64_M8_T8.out   ior_psx_n32_M4_T256.out
# ior_h5_n1_M2_T16.out    ior_mpi_n8_M1_T128.out  ior_psx_n32_M4_T32.out
# ior_h5_n1_M2_T256.out   ior_mpi_n8_M1_T16.out   ior_psx_n32_M4_T64.out
# ior_h5_n1_M2_T32.out    ior_mpi_n8_M1_T256.out  ior_psx_n32_M4_T8.out
# ior_h5_n1_M2_T64.out    ior_mpi_n8_M1_T32.out   ior_psx_n32_M8_T128.out
# ior_h5_n1_M2_T8.out     ior_mpi_n8_M1_T64.out   ior_psx_n32_M8_T16.out
# ior_h5_n1_M4_T128.out   ior_mpi_n8_M1_T8.out    ior_psx_n32_M8_T256.out
# ior_h5_n1_M4_T16.out    ior_mpi_n8_M2_T128.out  ior_psx_n32_M8_T32.out
# ior_h5_n1_M4_T256.out   ior_mpi_n8_M2_T16.out   ior_psx_n32_M8_T64.out
# ior_h5_n1_M4_T32.out    ior_mpi_n8_M2_T256.out  ior_psx_n32_M8_T8.out
# ior_h5_n1_M4_T64.out    ior_mpi_n8_M2_T32.out   ior_psx_n4_M1_T128.out
# ior_h5_n1_M4_T8.out     ior_mpi_n8_M2_T64.out   ior_psx_n4_M1_T16.out
# ior_h5_n1_M8_T128.out   ior_mpi_n8_M2_T8.out    ior_psx_n4_M1_T256.out
# ior_h5_n1_M8_T16.out    ior_mpi_n8_M4_T128.out  ior_psx_n4_M1_T32.out
# ior_h5_n1_M8_T256.out   ior_mpi_n8_M4_T16.out   ior_psx_n4_M1_T64.out
# ior_h5_n1_M8_T32.out    ior_mpi_n8_M4_T256.out  ior_psx_n4_M1_T8.out
# ior_h5_n1_M8_T64.out    ior_mpi_n8_M4_T32.out   ior_psx_n4_M2_T128.out
# ior_h5_n1_M8_T8.out     ior_mpi_n8_M4_T64.out   ior_psx_n4_M2_T16.out
# ior_h5_n2_M1_T128.out   ior_mpi_n8_M4_T8.out    ior_psx_n4_M2_T256.out
# ior_h5_n2_M1_T16.out    ior_mpi_n8_M8_T128.out  ior_psx_n4_M2_T32.out
# ior_h5_n2_M1_T256.out   ior_mpi_n8_M8_T16.out   ior_psx_n4_M2_T64.out
# ior_h5_n2_M1_T32.out    ior_mpi_n8_M8_T256.out  ior_psx_n4_M2_T8.out
# ior_h5_n2_M1_T64.out    ior_mpi_n8_M8_T32.out   ior_psx_n4_M4_T128.out
# ior_h5_n2_M1_T8.out     ior_mpi_n8_M8_T64.out   ior_psx_n4_M4_T16.out
# ior_h5_n2_M2_T128.out   ior_mpi_n8_M8_T8.out    ior_psx_n4_M4_T256.out
# ior_h5_n2_M2_T16.out    ior_out.csv             ior_psx_n4_M4_T32.out
# ior_h5_n2_M2_T256.out   ior_pnc_n16_M1_T128.out ior_psx_n4_M4_T64.out
# ior_h5_n2_M2_T32.out    ior_pnc_n16_M1_T16.out  ior_psx_n4_M4_T8.out
# ior_h5_n2_M2_T64.out    ior_pnc_n16_M1_T256.out ior_psx_n4_M8_T128.out
# ior_h5_n2_M2_T8.out     ior_pnc_n16_M1_T32.out  ior_psx_n4_M8_T16.out
# ior_h5_n2_M4_T128.out   ior_pnc_n16_M1_T64.out  ior_psx_n4_M8_T256.out
# ior_h5_n2_M4_T16.out    ior_pnc_n16_M1_T8.out   ior_psx_n4_M8_T32.out
# ior_h5_n2_M4_T256.out   ior_pnc_n16_M2_T128.out ior_psx_n4_M8_T64.out
# ior_h5_n2_M4_T32.out    ior_pnc_n16_M2_T16.out  ior_psx_n4_M8_T8.out
# ior_h5_n2_M4_T64.out    ior_pnc_n16_M2_T256.out ior_psx_n64_M1_T128.out
# ior_h5_n2_M4_T8.out     ior_pnc_n16_M2_T32.out  ior_psx_n64_M1_T16.out
# ior_h5_n2_M8_T128.out   ior_pnc_n16_M2_T64.out  ior_psx_n64_M1_T256.out
# ior_h5_n2_M8_T16.out    ior_pnc_n16_M2_T8.out   ior_psx_n64_M1_T32.out
# ior_h5_n2_M8_T256.out   ior_pnc_n16_M4_T128.out ior_psx_n64_M1_T64.out
# ior_h5_n2_M8_T32.out    ior_pnc_n16_M4_T16.out  ior_psx_n64_M1_T8.out
# ior_h5_n2_M8_T64.out    ior_pnc_n16_M4_T256.out ior_psx_n64_M2_T128.out
# ior_h5_n2_M8_T8.out     ior_pnc_n16_M4_T32.out  ior_psx_n64_M2_T16.out
# ior_h5_n32_M1_T128.out  ior_pnc_n16_M4_T64.out  ior_psx_n64_M2_T256.out
# ior_h5_n32_M1_T16.out   ior_pnc_n16_M4_T8.out   ior_psx_n64_M2_T32.out
# ior_h5_n32_M1_T256.out  ior_pnc_n16_M8_T128.out ior_psx_n64_M2_T64.out
# ior_h5_n32_M1_T32.out   ior_pnc_n16_M8_T16.out  ior_psx_n64_M2_T8.out
# ior_h5_n32_M1_T64.out   ior_pnc_n16_M8_T256.out ior_psx_n64_M4_T128.out
# ior_h5_n32_M1_T8.out    ior_pnc_n16_M8_T32.out  ior_psx_n64_M4_T16.out
# ior_h5_n32_M2_T128.out  ior_pnc_n16_M8_T64.out  ior_psx_n64_M4_T256.out
# ior_h5_n32_M2_T16.out   ior_pnc_n16_M8_T8.out   ior_psx_n64_M4_T32.out
# ior_h5_n32_M2_T256.out  ior_pnc_n1_M1_T128.out  ior_psx_n64_M4_T64.out
# ior_h5_n32_M2_T32.out   ior_pnc_n1_M1_T16.out   ior_psx_n64_M4_T8.out
# ior_h5_n32_M2_T64.out   ior_pnc_n1_M1_T256.out  ior_psx_n64_M8_T128.out
# ior_h5_n32_M2_T8.out    ior_pnc_n1_M1_T32.out   ior_psx_n64_M8_T16.out
# ior_h5_n32_M4_T128.out  ior_pnc_n1_M1_T64.out   ior_psx_n64_M8_T256.out
# ior_h5_n32_M4_T16.out   ior_pnc_n1_M1_T8.out    ior_psx_n64_M8_T32.out
# ior_h5_n32_M4_T256.out  ior_pnc_n1_M2_T128.out  ior_psx_n64_M8_T64.out
# ior_h5_n32_M4_T32.out   ior_pnc_n1_M2_T16.out   ior_psx_n64_M8_T8.out
# ior_h5_n32_M4_T64.out   ior_pnc_n1_M2_T256.out  ior_psx_n8_M1_T128.out
# ior_h5_n32_M4_T8.out    ior_pnc_n1_M2_T32.out   ior_psx_n8_M1_T16.out
# ior_h5_n32_M8_T128.out  ior_pnc_n1_M2_T64.out   ior_psx_n8_M1_T256.out
# ior_h5_n32_M8_T16.out   ior_pnc_n1_M2_T8.out    ior_psx_n8_M1_T32.out
# ior_h5_n32_M8_T256.out  ior_pnc_n1_M4_T128.out  ior_psx_n8_M1_T64.out
# ior_h5_n32_M8_T32.out   ior_pnc_n1_M4_T16.out   ior_psx_n8_M1_T8.out
# ior_h5_n32_M8_T64.out   ior_pnc_n1_M4_T256.out  ior_psx_n8_M2_T128.out
# ior_h5_n32_M8_T8.out    ior_pnc_n1_M4_T32.out   ior_psx_n8_M2_T16.out
# ior_h5_n4_M1_T128.out   ior_pnc_n1_M4_T64.out   ior_psx_n8_M2_T256.out
# ior_h5_n4_M1_T16.out    ior_pnc_n1_M4_T8.out    ior_psx_n8_M2_T32.out
# ior_h5_n4_M1_T256.out   ior_pnc_n1_M8_T128.out  ior_psx_n8_M2_T64.out
# ior_h5_n4_M1_T32.out    ior_pnc_n1_M8_T16.out   ior_psx_n8_M2_T8.out
# ior_h5_n4_M1_T64.out    ior_pnc_n1_M8_T256.out  ior_psx_n8_M4_T128.out
# ior_h5_n4_M1_T8.out     ior_pnc_n1_M8_T32.out   ior_psx_n8_M4_T16.out
# ior_h5_n4_M2_T128.out   ior_pnc_n1_M8_T64.out   ior_psx_n8_M4_T256.out
# ior_h5_n4_M2_T16.out    ior_pnc_n1_M8_T8.out    ior_psx_n8_M4_T32.out
# ior_h5_n4_M2_T256.out   ior_pnc_n2_M1_T128.out  ior_psx_n8_M4_T64.out
# ior_h5_n4_M2_T32.out    ior_pnc_n2_M1_T16.out   ior_psx_n8_M4_T8.out
# ior_h5_n4_M2_T64.out    ior_pnc_n2_M1_T256.out  ior_psx_n8_M8_T128.out
# ior_h5_n4_M2_T8.out     ior_pnc_n2_M1_T32.out   ior_psx_n8_M8_T16.out
# ior_h5_n4_M4_T128.out   ior_pnc_n2_M1_T64.out   ior_psx_n8_M8_T256.out
# ior_h5_n4_M4_T16.out    ior_pnc_n2_M1_T8.out    ior_psx_n8_M8_T32.out
# ior_h5_n4_M4_T256.out   ior_pnc_n2_M2_T128.out  ior_psx_n8_M8_T64.out
# ior_h5_n4_M4_T32.out    ior_pnc_n2_M2_T16.out   ior_psx_n8_M8_T8.out
# ior_h5_n4_M4_T64.out    ior_pnc_n2_M2_T256.out  ior_z5_n16_M1_T128.out
# ior_h5_n4_M4_T8.out     ior_pnc_n2_M2_T32.out   ior_z5_n16_M1_T16.out
# ior_h5_n4_M8_T128.out   ior_pnc_n2_M2_T64.out   ior_z5_n16_M1_T256.out
# ior_h5_n4_M8_T16.out    ior_pnc_n2_M2_T8.out    ior_z5_n16_M1_T32.out
# ior_h5_n4_M8_T256.out   ior_pnc_n2_M4_T128.out  ior_z5_n16_M1_T64.out
# ior_h5_n4_M8_T32.out    ior_pnc_n2_M4_T16.out   ior_z5_n16_M1_T8.out
# ior_h5_n4_M8_T64.out    ior_pnc_n2_M4_T256.out  ior_z5_n16_M2_T128.out
# ior_h5_n4_M8_T8.out     ior_pnc_n2_M4_T32.out   ior_z5_n16_M2_T16.out
# ior_h5_n64_M1_T128.out  ior_pnc_n2_M4_T64.out   ior_z5_n16_M2_T256.out
# ior_h5_n64_M1_T16.out   ior_pnc_n2_M4_T8.out    ior_z5_n16_M2_T32.out
# ior_h5_n64_M1_T256.out  ior_pnc_n2_M8_T128.out  ior_z5_n16_M2_T64.out
# ior_h5_n64_M1_T32.out   ior_pnc_n2_M8_T16.out   ior_z5_n16_M2_T8.out
# ior_h5_n64_M1_T64.out   ior_pnc_n2_M8_T256.out  ior_z5_n16_M4_T128.out
# ior_h5_n64_M1_T8.out    ior_pnc_n2_M8_T32.out   ior_z5_n16_M4_T16.out
# ior_h5_n64_M2_T128.out  ior_pnc_n2_M8_T64.out   ior_z5_n16_M4_T256.out
# ior_h5_n64_M2_T16.out   ior_pnc_n2_M8_T8.out    ior_z5_n16_M4_T32.out
# ior_h5_n64_M2_T256.out  ior_pnc_n32_M1_T128.out ior_z5_n16_M4_T64.out
# ior_h5_n64_M2_T32.out   ior_pnc_n32_M1_T16.out  ior_z5_n16_M4_T8.out
# ior_h5_n64_M2_T64.out   ior_pnc_n32_M1_T256.out ior_z5_n16_M8_T128.out
# ior_h5_n64_M2_T8.out    ior_pnc_n32_M1_T32.out  ior_z5_n16_M8_T16.out
# ior_h5_n64_M4_T128.out  ior_pnc_n32_M1_T64.out  ior_z5_n16_M8_T256.out
# ior_h5_n64_M4_T16.out   ior_pnc_n32_M1_T8.out   ior_z5_n16_M8_T32.out
# ior_h5_n64_M4_T256.out  ior_pnc_n32_M2_T128.out ior_z5_n16_M8_T64.out
# ior_h5_n64_M4_T32.out   ior_pnc_n32_M2_T16.out  ior_z5_n16_M8_T8.out
# ior_h5_n64_M4_T64.out   ior_pnc_n32_M2_T256.out ior_z5_n1_M1_T128.out
# ior_h5_n64_M4_T8.out    ior_pnc_n32_M2_T32.out  ior_z5_n1_M1_T16.out
# ior_h5_n64_M8_T128.out  ior_pnc_n32_M2_T64.out  ior_z5_n1_M1_T256.out
# ior_h5_n64_M8_T16.out   ior_pnc_n32_M2_T8.out   ior_z5_n1_M1_T32.out
# ior_h5_n64_M8_T32.out   ior_pnc_n32_M4_T128.out ior_z5_n1_M1_T64.out
# ior_h5_n64_M8_T64.out   ior_pnc_n32_M4_T16.out  ior_z5_n1_M1_T8.out
# ior_h5_n64_M8_T8.out    ior_pnc_n32_M4_T256.out ior_z5_n1_M2_T128.out
# ior_h5_n8_M1_T128.out   ior_pnc_n32_M4_T32.out  ior_z5_n1_M2_T16.out
# ior_h5_n8_M1_T16.out    ior_pnc_n32_M4_T64.out  ior_z5_n1_M2_T256.out
# ior_h5_n8_M1_T256.out   ior_pnc_n32_M4_T8.out   ior_z5_n1_M2_T32.out
# ior_h5_n8_M1_T32.out    ior_pnc_n32_M8_T128.out ior_z5_n1_M2_T64.out
# ior_h5_n8_M1_T64.out    ior_pnc_n32_M8_T16.out  ior_z5_n1_M2_T8.out
# ior_h5_n8_M1_T8.out     ior_pnc_n32_M8_T256.out ior_z5_n1_M4_T128.out
# ior_h5_n8_M2_T128.out   ior_pnc_n32_M8_T32.out  ior_z5_n1_M4_T16.out
# ior_h5_n8_M2_T16.out    ior_pnc_n32_M8_T64.out  ior_z5_n1_M4_T256.out
# ior_h5_n8_M2_T256.out   ior_pnc_n32_M8_T8.out   ior_z5_n1_M4_T32.out
# ior_h5_n8_M2_T32.out    ior_pnc_n4_M1_T128.out  ior_z5_n1_M4_T64.out
# ior_h5_n8_M2_T64.out    ior_pnc_n4_M1_T16.out   ior_z5_n1_M4_T8.out
# ior_h5_n8_M2_T8.out     ior_pnc_n4_M1_T256.out  ior_z5_n1_M8_T128.out
# ior_h5_n8_M4_T128.out   ior_pnc_n4_M1_T32.out   ior_z5_n1_M8_T16.out
# ior_h5_n8_M4_T16.out    ior_pnc_n4_M1_T64.out   ior_z5_n1_M8_T256.out
# ior_h5_n8_M4_T256.out   ior_pnc_n4_M1_T8.out    ior_z5_n1_M8_T32.out
# ior_h5_n8_M4_T32.out    ior_pnc_n4_M2_T128.out  ior_z5_n1_M8_T64.out
# ior_h5_n8_M4_T64.out    ior_pnc_n4_M2_T16.out   ior_z5_n1_M8_T8.out
# ior_h5_n8_M4_T8.out     ior_pnc_n4_M2_T256.out  ior_z5_n2_M1_T128.out
# ior_h5_n8_M8_T128.out   ior_pnc_n4_M2_T32.out   ior_z5_n2_M1_T16.out
# ior_h5_n8_M8_T16.out    ior_pnc_n4_M2_T64.out   ior_z5_n2_M1_T256.out
# ior_h5_n8_M8_T256.out   ior_pnc_n4_M2_T8.out    ior_z5_n2_M1_T32.out
# ior_h5_n8_M8_T32.out    ior_pnc_n4_M4_T128.out  ior_z5_n2_M1_T64.out
# ior_h5_n8_M8_T64.out    ior_pnc_n4_M4_T16.out   ior_z5_n2_M1_T8.out
# ior_h5_n8_M8_T8.out     ior_pnc_n4_M4_T256.out  ior_z5_n2_M2_T128.out
# ior_mpi_n16_M1_T128.out ior_pnc_n4_M4_T32.out   ior_z5_n2_M2_T16.out
# ior_mpi_n16_M1_T16.out  ior_pnc_n4_M4_T64.out   ior_z5_n2_M2_T256.out
# ior_mpi_n16_M1_T256.out ior_pnc_n4_M4_T8.out    ior_z5_n2_M2_T32.out
# ior_mpi_n16_M1_T32.out  ior_pnc_n4_M8_T128.out  ior_z5_n2_M2_T64.out
# ior_mpi_n16_M1_T64.out  ior_pnc_n4_M8_T16.out   ior_z5_n2_M2_T8.out
# ior_mpi_n16_M1_T8.out   ior_pnc_n4_M8_T256.out  ior_z5_n2_M4_T128.out
# ior_mpi_n16_M2_T128.out ior_pnc_n4_M8_T32.out   ior_z5_n2_M4_T16.out
# ior_mpi_n16_M2_T16.out  ior_pnc_n4_M8_T64.out   ior_z5_n2_M4_T256.out
# ior_mpi_n16_M2_T256.out ior_pnc_n4_M8_T8.out    ior_z5_n2_M4_T32.out
# ior_mpi_n16_M2_T32.out  ior_pnc_n64_M1_T128.out ior_z5_n2_M4_T64.out
# ior_mpi_n16_M2_T64.out  ior_pnc_n64_M1_T16.out  ior_z5_n2_M4_T8.out
# ior_mpi_n16_M2_T8.out   ior_pnc_n64_M1_T256.out ior_z5_n2_M8_T128.out
# ior_mpi_n16_M4_T128.out ior_pnc_n64_M1_T32.out  ior_z5_n2_M8_T16.out
# ior_mpi_n16_M4_T16.out  ior_pnc_n64_M1_T64.out  ior_z5_n2_M8_T256.out
# ior_mpi_n16_M4_T256.out ior_pnc_n64_M1_T8.out   ior_z5_n2_M8_T32.out
# ior_mpi_n16_M4_T32.out  ior_pnc_n64_M2_T128.out ior_z5_n2_M8_T64.out
# ior_mpi_n16_M4_T64.out  ior_pnc_n64_M2_T16.out  ior_z5_n2_M8_T8.out
# ior_mpi_n16_M4_T8.out   ior_pnc_n64_M2_T256.out ior_z5_n32_M1_T128.out
# ior_mpi_n16_M8_T128.out ior_pnc_n64_M2_T32.out  ior_z5_n32_M1_T16.out
# ior_mpi_n16_M8_T16.out  ior_pnc_n64_M2_T64.out  ior_z5_n32_M1_T256.out
# ior_mpi_n16_M8_T256.out ior_pnc_n64_M2_T8.out   ior_z5_n32_M1_T32.out
# ior_mpi_n16_M8_T32.out  ior_pnc_n64_M4_T128.out ior_z5_n32_M1_T64.out
# ior_mpi_n16_M8_T64.out  ior_pnc_n64_M4_T16.out  ior_z5_n32_M1_T8.out
# ior_mpi_n16_M8_T8.out   ior_pnc_n64_M4_T256.out ior_z5_n32_M2_T128.out
# ior_mpi_n1_M1_T128.out  ior_pnc_n64_M4_T32.out  ior_z5_n32_M2_T16.out
# ior_mpi_n1_M1_T16.out   ior_pnc_n64_M4_T64.out  ior_z5_n32_M2_T256.out
# ior_mpi_n1_M1_T256.out  ior_pnc_n64_M4_T8.out   ior_z5_n32_M2_T32.out
# ior_mpi_n1_M1_T32.out   ior_pnc_n64_M8_T128.out ior_z5_n32_M2_T64.out
# ior_mpi_n1_M1_T64.out   ior_pnc_n64_M8_T16.out  ior_z5_n32_M2_T8.out
# ior_mpi_n1_M1_T8.out    ior_pnc_n64_M8_T256.out ior_z5_n32_M4_T128.out
# ior_mpi_n1_M2_T128.out  ior_pnc_n64_M8_T32.out  ior_z5_n32_M4_T16.out
# ior_mpi_n1_M2_T16.out   ior_pnc_n64_M8_T64.out  ior_z5_n32_M4_T256.out
# ior_mpi_n1_M2_T256.out  ior_pnc_n64_M8_T8.out   ior_z5_n32_M4_T32.out
# ior_mpi_n1_M2_T32.out   ior_pnc_n8_M1_T128.out  ior_z5_n32_M4_T64.out
# ior_mpi_n1_M2_T64.out   ior_pnc_n8_M1_T16.out   ior_z5_n32_M4_T8.out
# ior_mpi_n1_M2_T8.out    ior_pnc_n8_M1_T256.out  ior_z5_n32_M8_T128.out
# ior_mpi_n1_M4_T128.out  ior_pnc_n8_M1_T32.out   ior_z5_n32_M8_T16.out
# ior_mpi_n1_M4_T16.out   ior_pnc_n8_M1_T64.out   ior_z5_n32_M8_T256.out
# ior_mpi_n1_M4_T256.out  ior_pnc_n8_M1_T8.out    ior_z5_n32_M8_T32.out
# ior_mpi_n1_M4_T32.out   ior_pnc_n8_M2_T128.out  ior_z5_n32_M8_T64.out
# ior_mpi_n1_M4_T64.out   ior_pnc_n8_M2_T16.out   ior_z5_n32_M8_T8.out
# ior_mpi_n1_M4_T8.out    ior_pnc_n8_M2_T256.out  ior_z5_n4_M1_T128.out
# ior_mpi_n1_M8_T128.out  ior_pnc_n8_M2_T32.out   ior_z5_n4_M1_T16.out
# ior_mpi_n1_M8_T16.out   ior_pnc_n8_M2_T64.out   ior_z5_n4_M1_T256.out
# ior_mpi_n1_M8_T256.out  ior_pnc_n8_M2_T8.out    ior_z5_n4_M1_T32.out
# ior_mpi_n1_M8_T32.out   ior_pnc_n8_M4_T128.out  ior_z5_n4_M1_T64.out
# ior_mpi_n1_M8_T64.out   ior_pnc_n8_M4_T16.out   ior_z5_n4_M1_T8.out
# ior_mpi_n1_M8_T8.out    ior_pnc_n8_M4_T256.out  ior_z5_n4_M2_T128.out
# ior_mpi_n2_M1_T128.out  ior_pnc_n8_M4_T32.out   ior_z5_n4_M2_T16.out
# ior_mpi_n2_M1_T16.out   ior_pnc_n8_M4_T64.out   ior_z5_n4_M2_T256.out
# ior_mpi_n2_M1_T256.out  ior_pnc_n8_M4_T8.out    ior_z5_n4_M2_T32.out
# ior_mpi_n2_M1_T32.out   ior_pnc_n8_M8_T128.out  ior_z5_n4_M2_T64.out
# ior_mpi_n2_M1_T64.out   ior_pnc_n8_M8_T16.out   ior_z5_n4_M2_T8.out
# ior_mpi_n2_M1_T8.out    ior_pnc_n8_M8_T256.out  ior_z5_n4_M4_T128.out
# ior_mpi_n2_M2_T128.out  ior_pnc_n8_M8_T32.out   ior_z5_n4_M4_T16.out
# ior_mpi_n2_M2_T16.out   ior_pnc_n8_M8_T64.out   ior_z5_n4_M4_T256.out
# ior_mpi_n2_M2_T256.out  ior_pnc_n8_M8_T8.out    ior_z5_n4_M4_T32.out
# ior_mpi_n2_M2_T32.out   ior_psx_n16_M1_T128.out ior_z5_n4_M4_T64.out
# ior_mpi_n2_M2_T64.out   ior_psx_n16_M1_T16.out  ior_z5_n4_M4_T8.out
# ior_mpi_n2_M2_T8.out    ior_psx_n16_M1_T256.out ior_z5_n4_M8_T128.out
# ior_mpi_n2_M4_T128.out  ior_psx_n16_M1_T32.out  ior_z5_n4_M8_T16.out
# ior_mpi_n2_M4_T16.out   ior_psx_n16_M1_T64.out  ior_z5_n4_M8_T256.out
# ior_mpi_n2_M4_T256.out  ior_psx_n16_M1_T8.out   ior_z5_n4_M8_T32.out
# ior_mpi_n2_M4_T32.out   ior_psx_n16_M2_T128.out ior_z5_n4_M8_T64.out
# ior_mpi_n2_M4_T64.out   ior_psx_n16_M2_T16.out  ior_z5_n4_M8_T8.out
# ior_mpi_n2_M4_T8.out    ior_psx_n16_M2_T256.out ior_z5_n64_M1_T128.out
# ior_mpi_n2_M8_T128.out  ior_psx_n16_M2_T32.out  ior_z5_n64_M1_T16.out
# ior_mpi_n2_M8_T16.out   ior_psx_n16_M2_T64.out  ior_z5_n64_M1_T256.out
# ior_mpi_n2_M8_T256.out  ior_psx_n16_M2_T8.out   ior_z5_n64_M1_T32.out
# ior_mpi_n2_M8_T32.out   ior_psx_n16_M4_T128.out ior_z5_n64_M1_T64.out
# ior_mpi_n2_M8_T64.out   ior_psx_n16_M4_T16.out  ior_z5_n64_M1_T8.out
# ior_mpi_n2_M8_T8.out    ior_psx_n16_M4_T256.out ior_z5_n64_M2_T128.out
# ior_mpi_n32_M1_T128.out ior_psx_n16_M4_T32.out  ior_z5_n64_M2_T16.out
# ior_mpi_n32_M1_T16.out  ior_psx_n16_M4_T64.out  ior_z5_n64_M2_T256.out
# ior_mpi_n32_M1_T256.out ior_psx_n16_M4_T8.out   ior_z5_n64_M2_T32.out
# ior_mpi_n32_M1_T32.out  ior_psx_n16_M8_T128.out ior_z5_n64_M2_T64.out
# ior_mpi_n32_M1_T64.out  ior_psx_n16_M8_T16.out  ior_z5_n64_M2_T8.out
# ior_mpi_n32_M1_T8.out   ior_psx_n16_M8_T256.out ior_z5_n64_M4_T128.out
# ior_mpi_n32_M2_T128.out ior_psx_n16_M8_T32.out  ior_z5_n64_M4_T16.out
# ior_mpi_n32_M2_T16.out  ior_psx_n16_M8_T64.out  ior_z5_n64_M4_T256.out
# ior_mpi_n32_M2_T256.out ior_psx_n16_M8_T8.out   ior_z5_n64_M4_T32.out
# ior_mpi_n32_M2_T32.out  ior_psx_n1_M1_T128.out  ior_z5_n64_M4_T64.out
# ior_mpi_n32_M2_T64.out  ior_psx_n1_M1_T16.out   ior_z5_n64_M4_T8.out
# ior_mpi_n32_M2_T8.out   ior_psx_n1_M1_T256.out  ior_z5_n64_M8_T128.out
# ior_mpi_n32_M4_T128.out ior_psx_n1_M1_T32.out   ior_z5_n64_M8_T16.out
# ior_mpi_n32_M4_T16.out  ior_psx_n1_M1_T64.out   ior_z5_n64_M8_T256.out
# ior_mpi_n32_M4_T256.out ior_psx_n1_M1_T8.out    ior_z5_n64_M8_T32.out
# ior_mpi_n32_M4_T32.out  ior_psx_n1_M2_T128.out  ior_z5_n64_M8_T64.out
# ior_mpi_n32_M4_T64.out  ior_psx_n1_M2_T16.out   ior_z5_n64_M8_T8.out
# ior_mpi_n32_M4_T8.out   ior_psx_n1_M2_T256.out  ior_z5_n8_M1_T128.out
# ior_mpi_n32_M8_T128.out ior_psx_n1_M2_T32.out   ior_z5_n8_M1_T16.out
# ior_mpi_n32_M8_T16.out  ior_psx_n1_M2_T64.out   ior_z5_n8_M1_T256.out
# ior_mpi_n32_M8_T256.out ior_psx_n1_M2_T8.out    ior_z5_n8_M1_T32.out
# ior_mpi_n32_M8_T32.out  ior_psx_n1_M4_T128.out  ior_z5_n8_M1_T64.out
# ior_mpi_n32_M8_T64.out  ior_psx_n1_M4_T16.out   ior_z5_n8_M1_T8.out
# ior_mpi_n32_M8_T8.out   ior_psx_n1_M4_T256.out  ior_z5_n8_M2_T128.out
# ior_mpi_n4_M1_T128.out  ior_psx_n1_M4_T32.out   ior_z5_n8_M2_T16.out
# ior_mpi_n4_M1_T16.out   ior_psx_n1_M4_T64.out   ior_z5_n8_M2_T256.out
# ior_mpi_n4_M1_T256.out  ior_psx_n1_M4_T8.out    ior_z5_n8_M2_T32.out
# ior_mpi_n4_M1_T32.out   ior_psx_n1_M8_T128.out  ior_z5_n8_M2_T64.out
# ior_mpi_n4_M1_T64.out   ior_psx_n1_M8_T16.out   ior_z5_n8_M2_T8.out
# ior_mpi_n4_M1_T8.out    ior_psx_n1_M8_T256.out  ior_z5_n8_M4_T128.out
# ior_mpi_n4_M2_T128.out  ior_psx_n1_M8_T32.out   ior_z5_n8_M4_T16.out
# ior_mpi_n4_M2_T16.out   ior_psx_n1_M8_T64.out   ior_z5_n8_M4_T256.out
# ior_mpi_n4_M2_T256.out  ior_psx_n1_M8_T8.out    ior_z5_n8_M4_T32.out
# ior_mpi_n4_M2_T32.out   ior_psx_n2_M1_T128.out  ior_z5_n8_M4_T64.out
# ior_mpi_n4_M2_T64.out   ior_psx_n2_M1_T16.out   ior_z5_n8_M4_T8.out
# ior_mpi_n4_M2_T8.out    ior_psx_n2_M1_T256.out  ior_z5_n8_M8_T128.out
# ior_mpi_n4_M4_T128.out  ior_psx_n2_M1_T32.out   ior_z5_n8_M8_T16.out
# ior_mpi_n4_M4_T16.out   ior_psx_n2_M1_T64.out   ior_z5_n8_M8_T256.out
# ior_mpi_n4_M4_T256.out  ior_psx_n2_M1_T8.out    ior_z5_n8_M8_T32.out
# ior_mpi_n4_M4_T32.out   ior_psx_n2_M2_T128.out  ior_z5_n8_M8_T64.out
# ior_mpi_n4_M4_T64.out   ior_psx_n2_M2_T16.out   ior_z5_n8_M8_T8.out

# %% [markdown]
# Now, let's pick an IOR output file and see what it looks like:

# %%
# !cat ../results/ior_mpi_n16_M1_T8.out
# Out:
# IOR-3.2.0: MPI Coordinated Test of Parallel I/O
# Began               : Thu Jun  6 17:14:12 2019
# Command line        : /glade/work/kpaul/software/ncar-ior/bin/ior -a MPIIO -w -r -C -i10 -g -t 8m -b 8m -c
# Machine             : Linux r14i0n9
# TestID              : 0
# StartTime           : Thu Jun  6 17:14:12 2019
# Path                : /gpfs/fs1/scratch/kpaul/ior_scaling
# FS                  : 15000.0 TiB   Used FS: 59.6%   Inodes: 2355.6 Mi   Used Inodes: 62.6%
#
# Options:
# api                 : MPIIO
# apiVersion          : (3.1)
# test filename       : testFile
# access              : single-shared-file
# type                : collective
# segments            : 1
# ordering in a file  : sequential
# ordering inter file : constant task offset
# task offset         : 1
# tasks               : 16
# clients per node    : 1
# repetitions         : 10
# xfersize            : 8 MiB
# blocksize           : 8 MiB
# aggregate filesize  : 128 MiB
#
# Results:
#
# access    bw(MiB/s)  block(KiB) xfer(KiB)  open(s)    wr/rd(s)   close(s)   total(s)   iter
# ------    ---------  ---------- ---------  --------   --------   --------   --------   ----
# write     9825       8192       8192       0.008057   0.004902   0.000072   0.013029   0
# read      3301.56    8192       8192       0.000735   0.037997   0.000037   0.038770   0
# remove    -          -          -          -          -          -          0.006272   0
# write     11551      8192       8192       0.006700   0.004311   0.000071   0.011081   1
# read      6323       8192       8192       0.000724   0.019474   0.000049   0.020242   1
# remove    -          -          -          -          -          -          0.007341   1
# write     9905       8192       8192       0.007578   0.004997   0.000337   0.012922   2
# read      8017       8192       8192       0.000982   0.014843   0.000145   0.015966   2
# remove    -          -          -          -          -          -          0.005234   2
# write     12243      8192       8192       0.006715   0.003665   0.000066   0.010455   3
# read      6897       8192       8192       0.000654   0.017841   0.000068   0.018559   3
# remove    -          -          -          -          -          -          0.005021   3
# write     11448      8192       8192       0.006460   0.004612   0.000104   0.011181   4
# read      8353       8192       8192       0.000853   0.014441   0.000033   0.015324   4
# remove    -          -          -          -          -          -          0.006028   4
# write     11431      8192       8192       0.006859   0.004280   0.000058   0.011198   5
# read      4385       8192       8192       0.001676   0.027492   0.000032   0.029193   5
# remove    -          -          -          -          -          -          0.005625   5
# write     10675      8192       8192       0.006785   0.005134   0.000067   0.011991   6
# read      7471       8192       8192       0.000913   0.016174   0.000034   0.017132   6
# remove    -          -          -          -          -          -          0.005223   6
# write     9759       8192       8192       0.008469   0.004585   0.000061   0.013116   7
# read      7670       8192       8192       0.000695   0.015934   0.000061   0.016689   7
# remove    -          -          -          -          -          -          0.005865   7
# write     10143      8192       8192       0.007601   0.004953   0.000064   0.012620   8
# read      2695.29    8192       8192       0.000932   0.046470   0.000089   0.047490   8
# remove    -          -          -          -          -          -          0.006420   8
# write     11637      8192       8192       0.006757   0.004154   0.000086   0.010999   9
# read      6782       8192       8192       0.000715   0.018127   0.000037   0.018873   9
# remove    -          -          -          -          -          -          0.004143   9
# Max Write: 12243.35 MiB/sec (12838.08 MB/sec)
# Max Read:  8352.85 MiB/sec (8758.60 MB/sec)
#
# Summary of all tests:
# Operation   Max(MiB)   Min(MiB)  Mean(MiB)     StdDev   Max(OPs)   Min(OPs)  Mean(OPs)     StdDev    Mean(s) Test# #Tasks tPN reps fPP reord reordoff reordrand seed segcnt   blksiz    xsize aggs(MiB)   API RefNum
# write       12243.35    9759.33   10861.67     860.81    1530.42    1219.92    1357.71     107.60    0.01186     0     16   1   10   0     1        1         0    0      1  8388608  8388608     128.0 MPIIO      0
# read         8352.85    2695.29    6189.48    1911.30    1044.11     336.91     773.68     238.91    0.02382     0     16   1   10   0     1        1         0    0      1  8388608  8388608     128.0 MPIIO      0
# Finished            : Thu Jun  6 17:14:12 2019

# %% [markdown]
# Okay, now let's write a function that parses a single IOR output file:

# %%
def read_ior_out(fname):
    ior_out = {}
    with open(fname) as f:
        ior_out['title'] = f.readline().strip()
        line = f.readline().strip()
        ior_out['header'] = {}
        while ':' in line:
            key,value = [x.strip() for x in line.split(':', 1)]
            ior_out['header'][key] = value
            line = f.readline().strip()
        f.readline()
        line = f.readline()
        ior_out['options'] = {}
        while ':' in line:
            key,value = [x.strip() for x in line.split(':', 1)]
            ior_out['options'][key] = value
            line = f.readline().strip()
        f.readline()
        f.readline()
        columns = f.readline().split()
        f.readline()
        line = f.readline().strip()
        ior_out['results'] = []
        while ':' not in line:
            vals = line.split()
            for i,v in enumerate(vals[1:-1]):
                vals[i+1] = None if v == '-' else float(v)
            vals[-1] = int(vals[-1])
            ior_out['results'].append({key:val for key, val in zip(columns, vals)})
            line = f.readline().strip()
        ior_out['max'] = {}
        ior_out['max']['write [MiB/sec]'] = float(line.split()[2])
        ior_out['max']['read [MiB/sec]'] = float(f.readline().split()[2])
        f.readline()
        f.readline()
        ior_out['summary'] = []
        columns = f.readline().split()
        vals = f.readline().split()
        vals[1:10] = [float(v) for v in vals[1:10]]
        vals[10:22] = [int(v) for v in vals[10:22]]
        vals[22] = float(vals[22])
        vals[-1] = int(vals[-1])
        ior_out['summary'].append({key:val for key, val in zip(columns, vals)})
        vals = f.readline().split()
        vals[1:10] = [float(v) for v in vals[1:10]]
        vals[10:22] = [int(v) for v in vals[10:22]]
        vals[22] = float(vals[22])
        vals[-1] = int(vals[-1])
        ior_out['summary'].append({key:val for key, val in zip(columns, vals)})
        key, value = [x.strip() for x in f.readline().split(' : ')]
        ior_out['header'][key] = value
    return ior_out

# %% [markdown]
# And test it...

# %%
read_ior_out('../results/ior_mpi_n16_M1_T8.out')
# Out:
# {'title': 'IOR-3.2.0: MPI Coordinated Test of Parallel I/O',
#  'header': {'Began': 'Thu Jun  6 17:14:12 2019',
#   'Command line': '/glade/work/kpaul/software/ncar-ior/bin/ior -a MPIIO -w -r -C -i10 -g -t 8m -b 8m -c',
#   'Machine': 'Linux r14i0n9',
#   'TestID': '0',
#   'StartTime': 'Thu Jun  6 17:14:12 2019',
#   'Path': '/gpfs/fs1/scratch/kpaul/ior_scaling',
#   'FS': '15000.0 TiB   Used FS: 59.6%   Inodes: 2355.6 Mi   Used Inodes: 62.6%',
#   'Finished': 'Thu Jun  6 17:14:12 2019'},
#  'options': {'api': 'MPIIO',
#   'apiVersion': '(3.1)',
#   'test filename': 'testFile',
#   'access': 'single-shared-file',
#   'type': 'collective',
#   'segments': '1',
#   'ordering in a file': 'sequential',
#   'ordering inter file': 'constant task offset',
#   'task offset': '1',
#   'tasks': '16',
#   'clients per node': '1',
#   'repetitions': '10',
#   'xfersize': '8 MiB',
#   'blocksize': '8 MiB',
#   'aggregate filesize': '128 MiB'},
#  'results': [{'access': 'write',
#    'bw(MiB/s)': 9825.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.008057,
#    'wr/rd(s)': 0.004902,
#    'close(s)': 7.2e-05,
#    'total(s)': 0.013029,
#    'iter': 0},
#   {'access': 'read',
#    'bw(MiB/s)': 3301.56,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000735,
#    'wr/rd(s)': 0.037997,
#    'close(s)': 3.7e-05,
#    'total(s)': 0.03877,
#    'iter': 0},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.006272,
#    'iter': 0},
#   {'access': 'write',
#    'bw(MiB/s)': 11551.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.0067,
#    'wr/rd(s)': 0.004311,
#    'close(s)': 7.1e-05,
#    'total(s)': 0.011081,
#    'iter': 1},
#   {'access': 'read',
#    'bw(MiB/s)': 6323.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000724,
#    'wr/rd(s)': 0.019474,
#    'close(s)': 4.9e-05,
#    'total(s)': 0.020242,
#    'iter': 1},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.007341,
#    'iter': 1},
#   {'access': 'write',
#    'bw(MiB/s)': 9905.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.007578,
#    'wr/rd(s)': 0.004997,
#    'close(s)': 0.000337,
#    'total(s)': 0.012922,
#    'iter': 2},
#   {'access': 'read',
#    'bw(MiB/s)': 8017.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000982,
#    'wr/rd(s)': 0.014843,
#    'close(s)': 0.000145,
#    'total(s)': 0.015966,
#    'iter': 2},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.005234,
#    'iter': 2},
#   {'access': 'write',
#    'bw(MiB/s)': 12243.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.006715,
#    'wr/rd(s)': 0.003665,
#    'close(s)': 6.6e-05,
#    'total(s)': 0.010455,
#    'iter': 3},
#   {'access': 'read',
#    'bw(MiB/s)': 6897.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000654,
#    'wr/rd(s)': 0.017841,
#    'close(s)': 6.8e-05,
#    'total(s)': 0.018559,
#    'iter': 3},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.005021,
#    'iter': 3},
#   {'access': 'write',
#    'bw(MiB/s)': 11448.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.00646,
#    'wr/rd(s)': 0.004612,
#    'close(s)': 0.000104,
#    'total(s)': 0.011181,
#    'iter': 4},
#   {'access': 'read',
#    'bw(MiB/s)': 8353.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000853,
#    'wr/rd(s)': 0.014441,
#    'close(s)': 3.3e-05,
#    'total(s)': 0.015324,
#    'iter': 4},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.006028,
#    'iter': 4},
#   {'access': 'write',
#    'bw(MiB/s)': 11431.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.006859,
#    'wr/rd(s)': 0.00428,
#    'close(s)': 5.8e-05,
#    'total(s)': 0.011198,
#    'iter': 5},
#   {'access': 'read',
#    'bw(MiB/s)': 4385.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.001676,
#    'wr/rd(s)': 0.027492,
#    'close(s)': 3.2e-05,
#    'total(s)': 0.029193,
#    'iter': 5},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.005625,
#    'iter': 5},
#   {'access': 'write',
#    'bw(MiB/s)': 10675.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.006785,
#    'wr/rd(s)': 0.005134,
#    'close(s)': 6.7e-05,
#    'total(s)': 0.011991,
#    'iter': 6},
#   {'access': 'read',
#    'bw(MiB/s)': 7471.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000913,
#    'wr/rd(s)': 0.016174,
#    'close(s)': 3.4e-05,
#    'total(s)': 0.017132,
#    'iter': 6},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.005223,
#    'iter': 6},
#   {'access': 'write',
#    'bw(MiB/s)': 9759.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.008469,
#    'wr/rd(s)': 0.004585,
#    'close(s)': 6.1e-05,
#    'total(s)': 0.013116,
#    'iter': 7},
#   {'access': 'read',
#    'bw(MiB/s)': 7670.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000695,
#    'wr/rd(s)': 0.015934,
#    'close(s)': 6.1e-05,
#    'total(s)': 0.016689,
#    'iter': 7},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.005865,
#    'iter': 7},
#   {'access': 'write',
#    'bw(MiB/s)': 10143.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.007601,
#    'wr/rd(s)': 0.004953,
#    'close(s)': 6.4e-05,
#    'total(s)': 0.01262,
#    'iter': 8},
#   {'access': 'read',
#    'bw(MiB/s)': 2695.29,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000932,
#    'wr/rd(s)': 0.04647,
#    'close(s)': 8.9e-05,
#    'total(s)': 0.04749,
#    'iter': 8},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.00642,
#    'iter': 8},
#   {'access': 'write',
#    'bw(MiB/s)': 11637.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.006757,
#    'wr/rd(s)': 0.004154,
#    'close(s)': 8.6e-05,
#    'total(s)': 0.010999,
#    'iter': 9},
#   {'access': 'read',
#    'bw(MiB/s)': 6782.0,
#    'block(KiB)': 8192.0,
#    'xfer(KiB)': 8192.0,
#    'open(s)': 0.000715,
#    'wr/rd(s)': 0.018127,
#    'close(s)': 3.7e-05,
#    'total(s)': 0.018873,
#    'iter': 9},
#   {'access': 'remove',
#    'bw(MiB/s)': None,
#    'block(KiB)': None,
#    'xfer(KiB)': None,
#    'open(s)': None,
#    'wr/rd(s)': None,
#    'close(s)': None,
#    'total(s)': 0.004143,
#    'iter': 9}],
#  'max': {'write [MiB/sec]': 12243.35, 'read [MiB/sec]': 8352.85},
#  'summary': [{'Operation': 'write',
#    'Max(MiB)': 12243.35,
#    'Min(MiB)': 9759.33,
#    'Mean(MiB)': 10861.67,
#    'StdDev': 107.6,
#    'Max(OPs)': 1530.42,
#    'Min(OPs)': 1219.92,
#    'Mean(OPs)': 1357.71,
#    'Mean(s)': 0.01186,
#    'Test#': 0,
#    '#Tasks': 16,
#    'tPN': 1,
#    'reps': 10,
#    'fPP': 0,
#    'reord': 1,
#    'reordoff': 1,
#    'reordrand': 0,
#    'seed': 0,
#    'segcnt': 1,
#    'blksiz': 8388608,
#    'xsize': 8388608,
#    'aggs(MiB)': 128.0,
#    'API': 'MPIIO',
#    'RefNum': 0},
#   {'Operation': 'read',
#    'Max(MiB)': 8352.85,
#    'Min(MiB)': 2695.29,
#    'Mean(MiB)': 6189.48,
#    'StdDev': 238.91,
#    'Max(OPs)': 1044.11,
#    'Min(OPs)': 336.91,
#    'Mean(OPs)': 773.68,
#    'Mean(s)': 0.02382,
#    'Test#': 0,
#    '#Tasks': 16,
#    'tPN': 1,
#    'reps': 10,
#    'fPP': 0,
#    'reord': 1,
#    'reordoff': 1,
#    'reordrand': 0,
#    'seed': 0,
#    'segcnt': 1,
#    'blksiz': 8388608,
#    'xsize': 8388608,
#    'aggs(MiB)': 128.0,
#    'API': 'MPIIO',
#    'RefNum': 0}]}

# %% [markdown]
# Great!  Now, let's write a function that extracts out the information we want into a DataFrame.  What information do we want?  For each dictionary in the `summary` section, we extract out:
#
# - `Max(MiB)` ==> `max[MiB/sec]`
# - `Min(MiB)` ==> `min[MiB/sec]`
# - `Mean(MiB)` ==> `mean[MiB/sec]`
# - `StdDev` ==> `std[MiB/sec]`
# - `#Tasks` ==> `nranks`
# - `blksiz` ==> `blocksize[B]`
# - `xsize` ==> `xfersize[B]`
# - `aggs(MiB)` ==> `totalsize[MiB]`
# - `API` ==> `api`
#
# This constitutes a single row in the DataFrame.

# %%
import glob
import pandas as pd

def make_dataframe(fnames='../results/ior_*.out'):
    data = {'api': [], 'nranks': [], 'xfersize[MiB]': [], 'blocksize[MiB]': [], 'totalsize[MiB]': [],
            'operation': [], 'min[MiB/sec]': [], 'max[MiB/sec]': [], 'mean[MiB/sec]': [], 'std[MiB/sec]': []}
    fnames = glob.glob(fnames)
    for fname in fnames:
        ior_out = read_ior_out(fname)
        for sumitem in ior_out['summary']:
            data['operation'].append(sumitem['Operation'])
            data['api'].append(sumitem['API'])
            data['nranks'].append(sumitem['#Tasks'])
            data['xfersize[MiB]'].append(sumitem['xsize'] / 1024**2)
            data['blocksize[MiB]'].append(sumitem['blksiz'] / 1024**2)
            data['totalsize[MiB]'].append(sumitem['aggs(MiB)'])
            data['min[MiB/sec]'].append(sumitem['Min(MiB)'])
            data['max[MiB/sec]'].append(sumitem['Max(MiB)'])
            data['mean[MiB/sec]'].append(sumitem['Mean(MiB)'])
            data['std[MiB/sec]'].append(sumitem['StdDev'])
    return pd.DataFrame(data)

# %%
df = make_dataframe()

# %%
df
# Out:
#         api  nranks  xfersize[MiB]  blocksize[MiB]  totalsize[MiB] operation  \
# 0        Z5       1          256.0          2048.0          2048.0     write
# 1        Z5       1          256.0          2048.0          2048.0      read
# 2      HDF5      32            8.0            64.0          2048.0     write
# 3      HDF5      32            8.0            64.0          2048.0      read
# 4     NCMPI      16          128.0           128.0          2048.0     write
# 5     NCMPI      16          128.0           128.0          2048.0      read
# 6      HDF5       4            8.0             8.0            32.0     write
# 7      HDF5       4            8.0             8.0            32.0      read
# 8     MPIIO       1           64.0           128.0           128.0     write
# 9     MPIIO       1           64.0           128.0           128.0      read
# 10       Z5       1           32.0            32.0            32.0     write
# 11       Z5       1           32.0            32.0            32.0      read
# 12    POSIX      16           16.0           128.0          2048.0     write
# 13    POSIX      16           16.0           128.0          2048.0      read
# 14    MPIIO      64          256.0          1024.0         65536.0     write
# 15    MPIIO      64          256.0          1024.0         65536.0      read
# 16    NCMPI       2          256.0          1024.0          2048.0     write
# 17    NCMPI       2          256.0          1024.0          2048.0      read
# 18    POSIX       8          128.0           256.0          2048.0     write
# 19    POSIX       8          128.0           256.0          2048.0      read
# 20    POSIX       4           64.0           512.0          2048.0     write
# 21    POSIX       4           64.0           512.0          2048.0      read
# 22    MPIIO      32           32.0            32.0          1024.0     write
# 23    MPIIO      32           32.0            32.0          1024.0      read
# 24    MPIIO      16           32.0            64.0          1024.0     write
# 25    MPIIO      16           32.0            64.0          1024.0      read
# 26     HDF5      64           16.0            32.0          2048.0     write
# 27     HDF5      64           16.0            32.0          2048.0      read
# 28       Z5       8          256.0           512.0          4096.0     write
# 29       Z5       8          256.0           512.0          4096.0      read
# ...     ...     ...            ...             ...             ...       ...
# 1648  POSIX       4          256.0          2048.0          8192.0     write
# 1649  POSIX       4          256.0          2048.0          8192.0      read
# 1650     Z5      16           64.0           128.0          2048.0     write
# 1651     Z5      16           64.0           128.0          2048.0      read
# 1652     Z5       4          128.0          1024.0          4096.0     write
# 1653     Z5       4          128.0          1024.0          4096.0      read
# 1654  POSIX      16          128.0           128.0          2048.0     write
# 1655  POSIX      16          128.0           128.0          2048.0      read
# 1656     Z5      32           64.0            64.0          2048.0     write
# 1657     Z5      32           64.0            64.0          2048.0      read
# 1658     Z5       2            8.0            32.0            64.0     write
# 1659     Z5       2            8.0            32.0            64.0      read
# 1660     Z5      64          256.0          1024.0         65536.0     write
# 1661     Z5      64          256.0          1024.0         65536.0      read
# 1662  MPIIO      32           32.0           128.0          4096.0     write
# 1663  MPIIO      32           32.0           128.0          4096.0      read
# 1664  POSIX       1            8.0            32.0            32.0     write
# 1665  POSIX       1            8.0            32.0            32.0      read
# 1666   HDF5       8          128.0           256.0          2048.0     write
# 1667   HDF5       8          128.0           256.0          2048.0      read
# 1668  MPIIO      64           32.0           256.0         16384.0     write
# 1669  MPIIO      64           32.0           256.0         16384.0      read
# 1670   HDF5      16           16.0           128.0          2048.0     write
# 1671   HDF5      16           16.0           128.0          2048.0      read
# 1672  MPIIO      32            8.0             8.0           256.0     write
# 1673  MPIIO      32            8.0             8.0           256.0      read
# 1674  NCMPI       1           16.0            16.0            16.0     write
# 1675  NCMPI       1           16.0            16.0            16.0      read
# 1676     Z5       8           64.0           256.0          2048.0     write
# 1677     Z5       8           64.0           256.0          2048.0      read
#
#       min[MiB/sec]  max[MiB/sec]  mean[MiB/sec]  std[MiB/sec]
# 0           462.11        568.80         553.34          0.12
# 1            90.59         90.88          90.84          0.00
# 2           732.16       5806.65        4404.77        192.54
# 3          6128.66      14749.42       10915.75        300.26
# 4          2141.02       3824.29        2741.30          3.97
# 5          5265.25      15086.45        7540.23         21.22
# 6           172.85        378.61         294.42          9.40
# 7          1090.59       2140.71        1890.39         44.33
# 8          3051.63       3160.40        3105.38          0.65
# 9          1671.03       3088.90        2677.78          6.24
# 10          361.22        574.52         548.45          1.95
# 11           85.61         89.46          87.47          0.04
# 12         3453.04      16130.40        9330.14        249.43
# 13        10633.59      23442.52       16786.78        212.44
# 14       129181.03     164762.99      145416.02         42.55
# 15        63313.76      86283.15       76817.58         34.02
# 16         3807.80       5850.31        5016.94          2.25
# 17         4516.61       6484.79        5282.88          2.15
# 18         2582.20      16070.58        9140.94         33.13
# 19         9092.54      21240.14       17271.11         31.28
# 20         6163.07      10736.65        9331.06         19.10
# 21        10658.72      13844.88       12117.02         13.80
# 22        34127.43      39089.63       37463.69         45.02
# 23         4477.20      14790.47       10333.12        111.30
# 24        28320.31      38024.39       34620.07         82.10
# 25         3740.95      14368.90       10269.13        102.99
# 26           28.47       4245.33        3261.33         73.07
# 27         6005.38      18368.71       14000.35        209.32
# 28         2037.56       4438.73        4007.50          2.73
# 29          635.25        720.83         708.45          0.10
# ...            ...           ...            ...           ...
# 1648      10496.55      12008.75       11574.57          1.69
# 1649      13890.51      14157.22       13987.00          0.26
# 1650       5580.86       8185.52        6965.22         12.74
# 1651       1274.37       1398.52        1342.57          0.52
# 1652       1973.64       2204.37        2106.57          0.64
# 1653        329.40        350.38         340.26          0.05
# 1654       4312.29      20473.18       13784.41         40.39
# 1655      18659.08      29486.58       23162.43         31.73
# 1656       4843.72       8272.43        6786.59         12.44
# 1657       1904.84       2835.29        2539.44          5.00
# 1658        671.98        773.78         738.43          4.52
# 1659         99.49        172.95         161.43          2.65
# 1660      27655.78      30956.82       29529.51          4.14
# 1661       5131.97       5494.60        5261.36          0.44
# 1662      63745.53      77634.21       69835.85        154.22
# 1663       8898.87      40538.97       29037.15        343.58
# 1664        339.12       1190.38         721.66         27.97
# 1665       7132.63       8271.37        7913.17         40.13
# 1666       1330.27       7378.33        6022.42         14.70
# 1667       6138.54       8698.02        7363.45          6.33
# 1668      47643.86     140086.98      112048.92        834.09
# 1669      34201.94      84037.57       58428.56        529.42
# 1670       1013.89       7353.78        5349.71        113.33
# 1671       6143.14      11370.36        8689.11         99.64
# 1672        260.50      14298.90       12099.20        497.04
# 1673       1869.23       5849.48        4298.83        144.99
# 1674        252.32        653.94         555.28          7.73
# 1675        421.35       1491.53         972.73         21.55
# 1676       2764.36       4004.08        3667.16          6.46
# 1677        686.61        709.65         696.74          0.10
#
# [1678 rows x 10 columns]

# %%
df.to_csv('../results/ior_out.csv', index=False)
